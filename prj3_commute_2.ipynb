# %% [markdown]
# ### 분석을 위해 출/퇴근 시간 데이터만 정리해보자

# %%
import pandas as pd

# %%
#승하차인원 정제된 데이터 엑셀파일로 읽어오기 : 읽는것도 오래 걸림  : 한글이 깨질때만 해봤음.
#data= pd.read_excel('./data2/부산일자별도시철도이용객수_v1.xlsx')
#data.head()

# %%
#승하차인원 정제된 데이터 csv파일 읽기
data2= pd.read_csv('./data2/부산일자별도시철도이용객수_v1.csv',engine='python')  #한글파일 csv인 경우 engin옵션 필요

# %%
data2.head()
# Out:
#           년월일  역번호       역명  구분  1시  2시  3시  4시  5시    6시  ...  15시  16시  17시  \
# 0  2018-01-01   95  다대포해수욕장  승차   0   0   0  12  37    63  ...  430  361  398
# 1  2018-01-01   95  다대포해수욕장  하차  12   7   0   1  53  1392  ...  286  294  319
# 2  2018-01-01   96     다대포항  승차   1   1   0   4  44    70  ...  182  179  165
# 3  2018-01-01   96     다대포항  하차  11   1   0   0  11    62  ...  186  193  191
# 4  2018-01-01   97       낫개  승차   1   1   0   9  78   159  ...  248  274  250
#
#    18시  19시  20시  21시  22시  23시  24시
# 0  221  129  110   87   59   12    6
# 1  182  179  139  134   89   76   48
# 2  129   90   63   54   27   11    2
# 3  198  155  143  128  115   68   42
# 4  171  146   61   78   65   22    1
#
# [5 rows x 28 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81760 entries, 0 to 81759
# Data columns (total 28 columns):
# 년월일    81760 non-null object
# 역번호    81760 non-null int64
# 역명     81760 non-null object
# 구분     81760 non-null object
# 1시     81760 non-null int64
# 2시     81760 non-null int64
# 3시     81760 non-null int64
# 4시     81760 non-null int64
# 5시     81760 non-null int64
# 6시     81760 non-null int64
# 7시     81760 non-null int64
# 8시     81760 non-null int64
# 9시     81760 non-null int64
# 10시    81760 non-null int64
# 11시    81760 non-null int64
# 12시    81760 non-null int64
# 13시    81760 non-null int64
# 14시    81760 non-null int64
# 15시    81760 non-null int64
# 16시    81760 non-null int64
# 17시    81760 non-null int64
# 18시    81760 non-null int64
# 19시    81760 non-null int64
# 20시    81760 non-null int64
# 21시    81760 non-null int64
# 22시    81760 non-null int64
# 23시    81760 non-null int64
# 24시    81760 non-null int64
# dtypes: int64(25), object(3)
# memory usage: 17.5+ MB

# %%
#역정보를 먼저 merge해야 일을 한번 할수 있을것 같다.
dinfo= pd.read_csv('./data2/부산교통공사_도시철도역사정보_20190520.csv',engine='python')  #한글파일 csv인 경우 engin옵션 필요
dinfo.head()
# Out:
#    역번호      역사명   노선번호         노선명           영문역사명    한자역사명 환승역구분 환승노선번호  \
# 0   95  다대포해수욕장  S2601  부산도시철도 1호선   Dadaepo Beach  多大浦海水浴場   일반역    NaN
# 1   96    다대포항역  S2601  부산도시철도 1호선  Dadaepo Harbor     多大浦港   일반역    NaN
# 2   97      낫개역  S2601  부산도시철도 1호선          Natgae      羅 浦   일반역    NaN
# 3   98     신장림역  S2601  부산도시철도 1호선      Sinjangnim      新長林   일반역    NaN
# 4   99      장림역  S2601  부산도시철도 1호선         Jangnim       長林   일반역    NaN
#
#   환승노선명        역위도         역경도   운영기관명               역사도로명주소        역사전화번호  \
# 0   NaN  35.089951  128.973971  부산교통공사  부산광역시 사하구 다대로 지하 692  051-678-6195
# 1   NaN  35.081631  128.977636  부산교통공사  부산광역시 사하구 다대로 지하 548  051-678-6196
# 2   NaN  35.074433  128.977041  부산교통공사  부산광역시 사하구 다대로 지하 422  051-678-6197
# 3   NaN  35.065265  128.979873  부산교통공사  부산광역시 사하구 다대로 지하 310  051-678-6198
# 4   NaN  35.057419  128.971279  부산교통공사  부산광역시 사하구 다대로 지하 230  051-618-6199
#
#       데이터기준일자
# 0  2019-05-20
# 1  2019-05-20
# 2  2019-05-20
# 3  2019-05-20
# 4  2019-05-20

# %%
#중동역이 지도에 표시가 안된다. 확인해보자
#dinfo[dinfo['역사명']=='중동역']
#역번호가 3자리대가 아닌 4자리이다. 데이터 전후 추이를 보아 하니 2020 -> 202로 변경이 필요하다
dinfo[dinfo['역번호']== 2020]
# Out:
#      역번호  역사명   노선번호         노선명      영문역사명 한자역사명 환승역구분 환승노선번호 환승노선명      역위도  \
# 41  2020  중동역  S2602  부산도시철도 2호선  Jung-dong    中洞   일반역    NaN   NaN  35.1667
#
#            역경도   운영기관명                 역사도로명주소        역사전화번호     데이터기준일자
# 41  129.168604  부산교통공사  부산광역시 해운대구 해운대로 지하 730  051-678-6202  2019-05-20

# %%
dinfo.loc[41,'역번호'] = '202'

# %%
#역사정보에서 역위도와 역경도정보만 가져오기
dinfo2=dinfo[['역번호','역위도','역경도']]
dinfo2.head()
# Out:
#   역번호        역위도         역경도
# 0  95  35.089951  128.973971
# 1  96  35.081631  128.977636
# 2  97  35.074433  128.977041
# 3  98  35.065265  128.979873
# 4  99  35.057419  128.971279

# %%
dinfo2['역번호']=dinfo2['역번호'].astype('int')
dinfo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 3 columns):
# 역번호    114 non-null int32
# 역위도    114 non-null float64
# 역경도    114 non-null float64
# dtypes: float64(2), int32(1)
# memory usage: 2.3 KB
# C:\python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dinfo2.head()
# Out:
#    역번호        역위도         역경도
# 0   95  35.089951  128.973971
# 1   96  35.081631  128.977636
# 2   97  35.074433  128.977041
# 3   98  35.065265  128.979873
# 4   99  35.057419  128.971279

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81760 entries, 0 to 81759
# Data columns (total 28 columns):
# 년월일    81760 non-null object
# 역번호    81760 non-null int64
# 역명     81760 non-null object
# 구분     81760 non-null object
# 1시     81760 non-null int64
# 2시     81760 non-null int64
# 3시     81760 non-null int64
# 4시     81760 non-null int64
# 5시     81760 non-null int64
# 6시     81760 non-null int64
# 7시     81760 non-null int64
# 8시     81760 non-null int64
# 9시     81760 non-null int64
# 10시    81760 non-null int64
# 11시    81760 non-null int64
# 12시    81760 non-null int64
# 13시    81760 non-null int64
# 14시    81760 non-null int64
# 15시    81760 non-null int64
# 16시    81760 non-null int64
# 17시    81760 non-null int64
# 18시    81760 non-null int64
# 19시    81760 non-null int64
# 20시    81760 non-null int64
# 21시    81760 non-null int64
# 22시    81760 non-null int64
# 23시    81760 non-null int64
# 24시    81760 non-null int64
# dtypes: int64(25), object(3)
# memory usage: 17.5+ MB

# %%
data3=data2

# %%
#승하차정보와 역정보를 merge하기 
df_m = pd.merge(data3,dinfo2, on ='역번호',how='inner')

# %%
df_m.tail()
# Out:
#               년월일  역번호  역명  구분  1시  2시  3시  4시  5시  6시  ...  17시  18시  19시  \
# 81755  2018-12-29  414  안평  하차   0   0   0   0   0  39  ...  158  119   82
# 81756  2018-12-30  414  안평  승차   0   0   0   0  17  24  ...   96   96   51
# 81757  2018-12-30  414  안평  하차   0   0   0   0   0  34  ...  106   90   46
# 81758  2018-12-31  414  안평  승차   0   0   0   2  34  55  ...  153  159   63
# 81759  2018-12-31  414  안평  하차   7   0   0   0   3  46  ...  147  222  126
#
#        20시  21시  22시  23시  24시        역위도         역경도
# 81755   77   65   70   54   29  35.237363  129.171823
# 81756   47   22   18    3    0  35.237363  129.171823
# 81757   78   57   59   34   17  35.237363  129.171823
# 81758   43   55   25    9    3  35.237363  129.171823
# 81759   77   75   64   42   23  35.237363  129.171823
#
# [5 rows x 30 columns]

# %% [markdown]
# * 1.출근시간 07~09 시 사이에 하차 하는 역별 이용객수 정보 (회사)
# * 4.퇴근시간 18-20 시 사이에 하차 하는 역별 이용객수 정보 (주택가)

# %%
#출근시간에 하차가 가장 많은 역 (회사가 많은 역)
#퇴근시간에 하차가 가장 많은 역 (주택가)
df_getoff = df_m.loc[df_m['구분']=='하차',['년월일','역번호','역명','7시','8시','18시','19시','역위도','역경도']]
df_getoff.head()
# Out:
#           년월일  역번호       역명    7시   8시  18시  19시        역위도         역경도
# 1  2018-01-01   95  다대포해수욕장  1419   78  182  179  35.089951  128.973971
# 3  2018-01-02   95  다대포해수욕장    87  100  361  277  35.089951  128.973971
# 5  2018-01-03   95  다대포해수욕장    74  120  332  347  35.089951  128.973971
# 7  2018-01-04   95  다대포해수욕장    82  129  349  281  35.089951  128.973971
# 9  2018-01-05   95  다대포해수욕장    99  126  369  319  35.089951  128.973971

# %% [markdown]
# ### 데이터를 가져왔으니 이제 분석을 해볼까? 1,2번은 회사 3,4번이 주택가로 추정되는 역이다.

# %%
#1.하차정보로만 확인해보기 
df_getoff.head()
# Out:
#           년월일  역번호       역명    7시   8시  18시  19시        역위도         역경도
# 1  2018-01-01   95  다대포해수욕장  1419   78  182  179  35.089951  128.973971
# 3  2018-01-02   95  다대포해수욕장    87  100  361  277  35.089951  128.973971
# 5  2018-01-03   95  다대포해수욕장    74  120  332  347  35.089951  128.973971
# 7  2018-01-04   95  다대포해수욕장    82  129  349  281  35.089951  128.973971
# 9  2018-01-05   95  다대포해수욕장    99  126  369  319  35.089951  128.973971

# %%
#출근시간 7시8시 합해서 아침이란 컬럼으로 새로생성
#퇴근시간 18시19시 합해서 저녁이란 컬럼으로 새로 생성
df_getoff['아침'] = df_getoff['7시']+df_getoff['8시']
df_getoff['저녁'] = df_getoff['18시']+df_getoff['19시']

# %%
df_getoff.head()
# Out:
#           년월일  역번호       역명    7시   8시  18시  19시        역위도         역경도    아침  \
# 1  2018-01-01   95  다대포해수욕장  1419   78  182  179  35.089951  128.973971  1497
# 3  2018-01-02   95  다대포해수욕장    87  100  361  277  35.089951  128.973971   187
# 5  2018-01-03   95  다대포해수욕장    74  120  332  347  35.089951  128.973971   194
# 7  2018-01-04   95  다대포해수욕장    82  129  349  281  35.089951  128.973971   211
# 9  2018-01-05   95  다대포해수욕장    99  126  369  319  35.089951  128.973971   225
#
#     저녁
# 1  361
# 3  638
# 5  679
# 7  630
# 9  688

# %%
#주중 평균으로 해야 조금더 정확할것 같다 토요일 일요일 제외하고 아침, 저녁 평균 이용객수를 산출하자
#주를 구하려면 년월일 컬럼을 date 타입으로 변경이 우선 필요하다.
df_getoff['년월일']=df_getoff['년월일'].astype('str')  # int -> str변환후 날짜 변환해야 함
df_getoff['년월일']=pd.to_datetime(df_getoff['년월일'])
df_getoff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40880 entries, 1 to 81759
# Data columns (total 11 columns):
# 년월일    40880 non-null datetime64[ns]
# 역번호    40880 non-null int64
# 역명     40880 non-null object
# 7시     40880 non-null int64
# 8시     40880 non-null int64
# 18시    40880 non-null int64
# 19시    40880 non-null int64
# 역위도    40880 non-null float64
# 역경도    40880 non-null float64
# 아침     40880 non-null int64
# 저녁     40880 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(1)
# memory usage: 3.7+ MB

# %%
#요일 반영하기
df_getoff['요일']= df_getoff['년월일'].dt.weekday.replace(0,'월').replace(1,'화').replace(2,'수').replace(3,'목').replace(4,'금').replace(5,'토').replace(6,'일')
df_getoff.tail()
# Out:
#              년월일  역번호  역명  7시   8시  18시  19시        역위도         역경도   아침   저녁  \
# 81751 2018-12-27  414  안평  72  144  208  129  35.237363  129.171823  216  337
# 81753 2018-12-28  414  안평  85  141  210  128  35.237363  129.171823  226  338
# 81755 2018-12-29  414  안평  47   64  119   82  35.237363  129.171823  111  201
# 81757 2018-12-30  414  안평  28   52   90   46  35.237363  129.171823   80  136
# 81759 2018-12-31  414  안평  50  120  222  126  35.237363  129.171823  170  348
#
#       요일
# 81751  목
# 81753  금
# 81755  토
# 81757  일
# 81759  월

# %%
#평일만 가져와서 데이터프레임 재구성해보자
df_getoff=df_getoff[df_getoff['요일'].isin(['월','화','수','목','금'])]
df_getoff.head()
# Out:
#          년월일  역번호       역명    7시   8시  18시  19시        역위도         역경도    아침  \
# 1 2018-01-01   95  다대포해수욕장  1419   78  182  179  35.089951  128.973971  1497
# 3 2018-01-02   95  다대포해수욕장    87  100  361  277  35.089951  128.973971   187
# 5 2018-01-03   95  다대포해수욕장    74  120  332  347  35.089951  128.973971   194
# 7 2018-01-04   95  다대포해수욕장    82  129  349  281  35.089951  128.973971   211
# 9 2018-01-05   95  다대포해수욕장    99  126  369  319  35.089951  128.973971   225
#
#     저녁 요일
# 1  361  월
# 3  638  화
# 5  679  수
# 7  630  목
# 9  688  금

# %%
#group by로  일평균 아침 / 저녁 하차 수를 역별로 계산해보자
dfg_getoff_day= df_getoff.groupby(['역번호','역명','역위도','역경도'])['아침','저녁'].mean()
dfg_getoff_day
# Out:
#                                            아침           저녁
# 역번호 역명      역위도       역경도
# 95  다대포해수욕장 35.089951 128.973971   248.352490   728.747126
# 96  다대포항    35.081631 128.977636   366.061303   757.628352
# 97  낫개      35.074433 128.977041   324.049808  1152.712644
# 98  신장림     35.065265 128.979873   433.701149   547.988506
# 99  장림      35.057419 128.971279   665.233716   500.463602
# 100 동매      35.048621 128.965908   887.613027   556.283525
# 101 신평      35.095179 128.960564  1677.114943  1241.130268
# 102 하단      35.106180 128.966803  3099.670498  3336.122605
# 103 당리      35.103532 128.973846   816.038314  1473.134100
# 104 사하      35.099847 128.983100   392.413793   864.295019
# 105 괴정      35.099816 128.992144   950.915709  2110.126437
# 106 대티      35.103126 128.999936   434.107280   740.808429
# 107 서대신     35.110937 129.012178   593.325670   474.961686
# 108 동대신     35.110452 129.017684   705.406130  1222.701149
# 109 토성      35.100727 129.019776  2236.996169  1072.268199
# 110 자갈치     35.097372 129.026670  2006.375479  2652.770115
# 111 남포      35.097953 129.034869  2852.436782  3407.237548
# 112 중앙      35.103837 129.036371  5018.249042   798.505747
# 113 부산역     35.115224 129.039700  4489.107280  3103.103448
# 114 초량      35.121168 129.043039  1774.268199   767.578544
# 115 부산진     35.127787 129.047894  2035.107280  1146.842912
# 116 좌천      35.134361 129.054455   738.678161   547.482759
# 117 범일      35.140952 129.059352  2597.337165  2267.950192
# 118 범내골     35.147400 129.059261  2330.961686  1456.245211
# 119 1서면     35.158282 129.059556  3907.298851  8624.195402
# 120 부전      35.162587 129.062952  1817.390805  2167.712644
# 121 양정      35.173122 129.071366  2751.800766  2554.532567
# 122 시청      35.179837 129.076642  2735.540230  2723.000000
# 123 1연산     35.186168 129.081534  2584.137931  4510.360153
# 124 교대      35.196050 129.080035  2237.835249  2938.988506
# ...                                       ...          ...
# 243 양산      35.338728 129.026391   799.425287  1101.773946
# 302 망미      35.171528 129.108225   429.095785  1093.574713
# 303 배산      35.173504 129.095498   500.651341  1009.494253
# 304 물만골     35.176808 129.085748   355.816092   603.781609
# 305 3연산     35.186173 129.081526  1594.885057  1761.862069
# 306 거제      35.188589 129.073941  1604.919540   730.701149
# 307 종합운동장   35.191250 129.067504   761.199234  1184.816092
# 308 사직      35.198998 129.064996   593.693487  1597.766284
# 309 미남      35.205503 129.068061   939.639847  2024.616858
# 310 만덕      35.213000 129.036527   464.494253  1401.632184
# 311 남산정     35.213340 129.023928   469.153257  1046.616858
# 312 숙등      35.211970 129.012749   617.318008   642.747126
# 313 3덕천     35.210215 129.005671  1258.383142  2471.547893
# 314 구포      35.206697 128.996366   773.885057   648.099617
# 315 강서구청    35.211247 128.981756  1127.674330   164.291188
# 316 체육공원    35.212577 128.969651   282.620690    53.371648
# 317 대저      35.213386 128.961049  2122.628352   988.846743
# 402 4동래     35.204834 129.077082   358.191571   519.003831
# 403 수안      35.201828 129.083806   555.049808   593.363985
# 404 낙민      35.200254 129.090774   315.003831   343.122605
# 405 충렬사     35.199859 129.097636   484.080460   689.467433
# 406 명장      35.205143 129.101517   306.291188   681.812261
# 407 서동      35.213333 129.107683   405.632184   457.203065
# 408 금사      35.215829 129.115153   698.272031   235.766284
# 409 반여농산물   35.217779 129.124061   581.697318   261.360153
# 410 석대      35.218112 129.137179    42.233716     9.237548
# 411 영산대     35.225777 129.146149   391.084291   652.747126
# 412 동부산대    35.232506 129.154024   230.429119   558.735632
# 413 고촌      35.236031 129.160444    90.750958    93.544061
# 414 안평      35.237363 129.171823   248.731801   366.356322
#
# [112 rows x 2 columns]

# %%
#인덱스 리셋
dfg_getoff_day = dfg_getoff_day.reset_index()
dfg_getoff_day.head()
# Out:
#    역번호       역명        역위도         역경도          아침           저녁
# 0   95  다대포해수욕장  35.089951  128.973971  248.352490   728.747126
# 1   96     다대포항  35.081631  128.977636  366.061303   757.628352
# 2   97       낫개  35.074433  128.977041  324.049808  1152.712644
# 3   98      신장림  35.065265  128.979873  433.701149   547.988506
# 4   99       장림  35.057419  128.971279  665.233716   500.463602

# %%
#아침 하차상위 top 30 
dfg_getoff_day=dfg_getoff_day.sort_values(by='아침',ascending=False)
getoff_am_top=dfg_getoff_day.head(30)
getoff_am_top.head()
# Out:
#     역번호    역명        역위도         역경도           아침           저녁
# 17  112    중앙  35.103837  129.036371  5018.249042   798.505747
# 18  113   부산역  35.115224  129.039700  4489.107280  3103.103448
# 24  119   1서면  35.158282  129.059556  3907.298851  8624.195402
# 66  227    사상  35.162361  128.984621  3738.540230  3995.210728
# 45  206  센텀시티  35.168827  129.131745  3508.616858  2626.452107

# %%
getoff_am_top = getoff_am_top.reset_index()

getoff_am_top.head()
# Out:
#    index  역번호    역명        역위도         역경도           아침           저녁
# 0     17  112    중앙  35.103837  129.036371  5018.249042   798.505747
# 1     18  113   부산역  35.115224  129.039700  4489.107280  3103.103448
# 2     24  119   1서면  35.158282  129.059556  3907.298851  8624.195402
# 3     66  227    사상  35.162361  128.984621  3738.540230  3995.210728
# 4     45  206  센텀시티  35.168827  129.131745  3508.616858  2626.452107

# %%
del getoff_am_top['index']
getoff_am_top.head()
# Out:
#    역번호    역명        역위도         역경도           아침           저녁
# 0  112    중앙  35.103837  129.036371  5018.249042   798.505747
# 1  113   부산역  35.115224  129.039700  4489.107280  3103.103448
# 2  119   1서면  35.158282  129.059556  3907.298851  8624.195402
# 3  227    사상  35.162361  128.984621  3738.540230  3995.210728
# 4  206  센텀시티  35.168827  129.131745  3508.616858  2626.452107

# %%
#저녁 하차상위 top 30 
dfg_getoff_day=dfg_getoff_day.sort_values(by='저녁',ascending=False)
getoff_pm_top=dfg_getoff_day.head(30)

# %%
getoff_pm_top = getoff_pm_top.reset_index()
del getoff_pm_top['index']
getoff_pm_top.head()
# Out:
#    역번호   역명        역위도         역경도           아침           저녁
# 0  119  1서면  35.158282  129.059556  3907.298851  8624.195402
# 1  219  2서면  35.157740  129.059084  2957.655172  5946.766284
# 2  125  1동래  35.205641  129.078506  2004.180077  4772.417625
# 3  123  1연산  35.186168  129.081534  2584.137931  4510.360153
# 4  227   사상  35.162361  128.984621  3738.540230  3995.210728

# %%
#지도 시각화 
import folium
map_osm = folium.Map(location=[35.166804,129.083479], zoom_start=12)   # 지도 초기 로딩위치

# %%
getoff_am_top.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
#지도로 출근시간(아침) 이용객 30개 역 표시
for item in getoff_am_top.index:
    lat = getoff_am_top.loc[item,'역위도']
    long = getoff_am_top.loc[item,'역경도']
    folium.CircleMarker([lat,long],  #위도/경도
                        radius=getoff_am_top.loc[item,'아침']/200,
                        popup=getoff_am_top.loc[item,'역명'],
                        color ='blue',
                        fill = True).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도로 퇴근시간(저녁) 상위 30개 이용객 표시 
for item in getoff_pm_top.index:
    lat = getoff_pm_top.loc[item,'역위도']
    long = getoff_pm_top.loc[item,'역경도']
    folium.CircleMarker([lat,long],  #위도/경도
                        radius=getoff_pm_top.loc[item,'저녁']/200,
                        popup=getoff_pm_top.loc[item,'역명'],
                        color ='red',
                        fill = True).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 1차  하차 분석 내용

# %% [markdown]
# 1. 파란색(출근)만 있는 경우의 역들은  주요 직장((일자리)이 우세한 역이라고 볼수 있다. (중앙, 신평, 토성, 부산진, 범내골, 전포, 거제, 모덕, 대저, 덕포 등)
# 2. 빨간색(퇴근)만 있는 경우 역들은 주요 주거지역(주택가)이 더 우세하다고 볼수 있다. (화명, 덕천, 구서, 장전, 온천장, 명륜, 미남, 대연, 광안,수영, 해운대, 장산)
# 3. 둘다 top 30 에 들어간 역들은 주거지역과 일자리 지역이 혼재 된 지역이라 볼 수 있다. (센텀시티, 연산, 교대, 동래, 하단)
# 4. 서면과 부산역의 경우 부산의 중심지로서 주거/일자리와 상관없이 이용객이 많다고 볼수 있고, 부산대와 경성대부경대역은 대학생들의 이용객이 많아서 출근시간(파란색)대에 top30안에 포함된것으로 추정된다.

# %% [markdown]
# ## 승차기준으로 데이터 분석

# %% [markdown]
# * 2.퇴근시간 18~20 시 사이에 승차 하는 역별 이용객수 정보(회사)
# * 3.출근시간 07~09 시 사이에 승차 하는 역별 이용객수 정보(주택가)

# %%
#출근시간에 승차가 가장 많은 역 (주택가)
#퇴근시간에 승차가 가장 많은 역 (회사)
df_geton = df_m.loc[df_m['구분']=='승차',['년월일','역번호','역명','7시','8시','18시','19시','역위도','역경도']]
df_geton.head()
# Out:
#           년월일  역번호       역명   7시    8시  18시  19시        역위도         역경도
# 0  2018-01-01   95  다대포해수욕장  925  1653  221  129  35.089951  128.973971
# 2  2018-01-02   95  다대포해수욕장  404   377  236  151  35.089951  128.973971
# 4  2018-01-03   95  다대포해수욕장  386   421  265  124  35.089951  128.973971
# 6  2018-01-04   95  다대포해수욕장  398   419  239  101  35.089951  128.973971
# 8  2018-01-05   95  다대포해수욕장  356   427  271  160  35.089951  128.973971

# %%
#출근시간 7시8시 합해서 아침이란 컬럼으로 새로생성
#퇴근시간 18시19시 합해서 저녁이란 컬럼으로 새로 생성
df_geton['아침'] = df_geton['7시'] + df_geton['8시']
df_geton['저녁'] = df_geton['18시']+ df_geton['19시']
df_getoff.head()
# Out:
#          년월일  역번호       역명    7시   8시  18시  19시        역위도         역경도    아침  \
# 1 2018-01-01   95  다대포해수욕장  1419   78  182  179  35.089951  128.973971  1497
# 3 2018-01-02   95  다대포해수욕장    87  100  361  277  35.089951  128.973971   187
# 5 2018-01-03   95  다대포해수욕장    74  120  332  347  35.089951  128.973971   194
# 7 2018-01-04   95  다대포해수욕장    82  129  349  281  35.089951  128.973971   211
# 9 2018-01-05   95  다대포해수욕장    99  126  369  319  35.089951  128.973971   225
#
#     저녁 요일
# 1  361  월
# 3  638  화
# 5  679  수
# 7  630  목
# 9  688  금

# %%
#주중 평균으로 해야 조금더 정확할것 같다 토요일 일요일 제외하고 아침, 저녁 평균 이용객수를 산출하자
#주를 구하려면 년월일 컬럼을 date 타입으로 변경이 우선 필요하다.
df_geton['년월일']=df_geton['년월일'].astype('str')  # int -> str변환후 날짜 변환해야 함
df_geton['년월일']=pd.to_datetime(df_geton['년월일'])
df_geton.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40880 entries, 0 to 81758
# Data columns (total 11 columns):
# 년월일    40880 non-null datetime64[ns]
# 역번호    40880 non-null int64
# 역명     40880 non-null object
# 7시     40880 non-null int64
# 8시     40880 non-null int64
# 18시    40880 non-null int64
# 19시    40880 non-null int64
# 역위도    40880 non-null float64
# 역경도    40880 non-null float64
# 아침     40880 non-null int64
# 저녁     40880 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(1)
# memory usage: 3.7+ MB

# %%
#요일 반영하기
df_geton['요일']= df_geton['년월일'].dt.weekday.replace(0,'월').replace(1,'화').replace(2,'수').replace(3,'목').replace(4,'금').replace(5,'토').replace(6,'일')
df_geton.tail()
# Out:
#              년월일  역번호  역명   7시   8시  18시  19시        역위도         역경도   아침  \
# 81750 2018-12-27  414  안평  209  204  189   48  35.237363  129.171823  413
# 81752 2018-12-28  414  안평  196  193  196   91  35.237363  129.171823  389
# 81754 2018-12-29  414  안평   75  113  123   53  35.237363  129.171823  188
# 81756 2018-12-30  414  안평   49   89   96   51  35.237363  129.171823  138
# 81758 2018-12-31  414  안평  159  175  159   63  35.237363  129.171823  334
#
#         저녁 요일
# 81750  237  목
# 81752  287  금
# 81754  176  토
# 81756  147  일
# 81758  222  월

# %%
#group by로  일평균 아침 / 저녁 승차 수를 역별로 계산해보자
df_geton_day= df_geton.groupby(['역번호','역명','역위도','역경도'])['아침','저녁'].mean()
df_geton_day.head()
# Out:
#                                            아침          저녁
# 역번호 역명      역위도       역경도
# 95  다대포해수욕장 35.089951 128.973971   797.054795  469.312329
# 96  다대포항    35.081631 128.977636   547.087671  360.769863
# 97  낫개      35.074433 128.977041  1054.460274  419.758904
# 98  신장림     35.065265 128.979873   631.410959  347.232877
# 99  장림      35.057419 128.971279   475.920548  463.895890

# %%
#아침 승차 상위 top 30 
df_geton_day=df_geton_day.sort_values(by='아침',ascending=False)
geton_am_top=df_geton_day.head(30)
geton_am_top
# Out:
#                                           아침           저녁
# 역번호 역명     역위도       역경도
# 123 1연산    35.186168 129.081534  2988.969863  2724.928767
# 127 온천장    35.220249 129.086437  2895.197260  1835.394521
# 124 교대     35.196050 129.080035  2779.046575  1984.375342
# 102 하단     35.106180 128.966803  2735.465753  3269.120548
# 201 장산     35.169914 129.176986  2588.654795  2070.638356
# 125 1동래    35.205641 129.078506  2567.649315  2119.824658
# 208 수영     35.165227 129.114713  2559.890411  1659.857534
# 212 경성대부경대 35.137585 129.100548  2180.997260  2921.895890
# 227 사상     35.162361 128.984621  2174.693151  4107.769863
# 129 장전     35.238091 129.088111  2049.909589  1334.846575
# 122 시청     35.179837 129.076642  2040.427397  2191.106849
# 309 미남     35.205503 129.068061  2037.323288  1001.556164
# 235 화명     35.236278 129.013918  1967.145205  1135.676712
# 121 양정     35.173122 129.071366  1889.684932  1891.331507
# 120 부전     35.162587 129.062952  1851.186301  2215.454795
# 105 괴정     35.099816 128.992144  1781.027397  1170.709589
# 128 부산대    35.229609 129.089358  1771.424658  2845.449315
# 119 1서면    35.158282 129.059556  1726.712329  6926.323288
# 223 개금     35.153284 129.020533  1717.093151   806.304110
# 131 두실     35.256959 129.091386  1582.082192   833.641096
# 213 대연     35.135153 129.092161  1570.046575  1112.953425
# 209 광안     35.157916 129.113168  1561.673973  1198.898630
# 234 수정     35.223356 129.009198  1561.090411   607.008219
# 130 구서     35.247407 129.091327  1539.386301  1430.572603
# 126 명륜     35.212551 129.079659  1520.854795  1308.624658
# 133 범어사    35.273105 129.092679  1437.709589  1035.210959
# 311 남산정    35.213340 129.023928  1378.213699   430.780822
# 205 벡스코    35.168844 129.138933  1377.098630  1094.800000
# 134 노포     35.284687 129.094967  1365.780822  2144.057534
# 308 사직     35.198998 129.064996  1356.473973   703.284932

# %%
geton_am_top = geton_am_top.reset_index()
geton_am_top.head()
# Out:
#    역번호   역명        역위도         역경도           아침           저녁
# 0  123  1연산  35.186168  129.081534  2988.969863  2724.928767
# 1  127  온천장  35.220249  129.086437  2895.197260  1835.394521
# 2  124   교대  35.196050  129.080035  2779.046575  1984.375342
# 3  102   하단  35.106180  128.966803  2735.465753  3269.120548
# 4  201   장산  35.169914  129.176986  2588.654795  2070.638356

# %%
#저녁 승차 상위 top 30 
df_geton_day=df_geton_day.sort_values(by='저녁',ascending=False)
geton_pm_top=df_geton_day.head(30)

# %%
geton_pm_top
# Out:
#                                           아침           저녁
# 역번호 역명     역위도       역경도
# 119 1서면    35.158282 129.059556  1726.712329  6926.323288
# 206 센텀시티   35.168827 129.131745  1017.202740  5037.479452
# 219 2서면    35.157740 129.059084  1208.567123  4873.791781
# 111 남포     35.097953 129.034869  1330.339726  4204.605479
# 227 사상     35.162361 128.984621  2174.693151  4107.769863
# 113 부산역    35.115224 129.039700  1352.046575  4061.690411
# 112 중앙     35.103837 129.036371   590.235616  3317.515068
# 110 자갈치    35.097372 129.026670   886.490411  3296.950685
# 102 하단     35.106180 128.966803  2735.465753  3269.120548
# 212 경성대부경대 35.137585 129.100548  2180.997260  2921.895890
# 117 범일     35.140952 129.059352  1046.419178  2857.641096
# 128 부산대    35.229609 129.089358  1771.424658  2845.449315
# 123 1연산    35.186168 129.081534  2988.969863  2724.928767
# 120 부전     35.162587 129.062952  1851.186301  2215.454795
# 122 시청     35.179837 129.076642  2040.427397  2191.106849
# 134 노포     35.284687 129.094967  1365.780822  2144.057534
# 125 1동래    35.205641 129.078506  2567.649315  2119.824658
# 201 장산     35.169914 129.176986  2588.654795  2070.638356
# 124 교대     35.196050 129.080035  2779.046575  1984.375342
# 317 대저     35.213386 128.961049  1026.419178  1943.904110
# 203 해운대    35.163672 129.158908   957.750685  1911.769863
# 121 양정     35.173122 129.071366  1889.684932  1891.331507
# 127 온천장    35.220249 129.086437  2895.197260  1835.394521
# 208 수영     35.165227 129.114713  2559.890411  1659.857534
# 313 3덕천    35.210215 129.005671  1211.205479  1615.739726
# 118 범내골    35.147400 129.059261  1171.008219  1588.178082
# 115 부산진    35.127787 129.047894   956.739726  1584.219178
# 305 3연산    35.186173 129.081526   914.739726  1498.043836
# 130 구서     35.247407 129.091327  1539.386301  1430.572603
# 129 장전     35.238091 129.088111  2049.909589  1334.846575

# %%
geton_pm_top = geton_pm_top.reset_index()
geton_pm_top.head()
# Out:
#    역번호    역명        역위도         역경도           아침           저녁
# 0  119   1서면  35.158282  129.059556  1726.712329  6926.323288
# 1  206  센텀시티  35.168827  129.131745  1017.202740  5037.479452
# 2  219   2서면  35.157740  129.059084  1208.567123  4873.791781
# 3  111    남포  35.097953  129.034869  1330.339726  4204.605479
# 4  227    사상  35.162361  128.984621  2174.693151  4107.769863

# %% [markdown]
# ### 승차 정보 시각화

# %%
#지도 시각화 
map_osm = folium.Map(location=[35.166804,129.083479], zoom_start=12)   # 지도 초기 로딩위치

# %%
geton_am_top.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
#지도로 출근시간(아침) 이용객 30개 역 표시  : 승차기준
for item in geton_am_top.index:
    lat = geton_am_top.loc[item,'역위도']
    long = geton_am_top.loc[item,'역경도']
    folium.CircleMarker([lat,long],  #위도/경도
                        radius=geton_am_top.loc[item,'아침']/200,
                        popup=geton_am_top.loc[item,'역명'],
                        color ='blue',
                        fill = True).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도로 퇴근시간(저녁) 상위 30개 이용객 표시 : 승차기준
for item in geton_pm_top.index:
    lat = geton_pm_top.loc[item,'역위도']
    long = geton_pm_top.loc[item,'역경도']
    folium.CircleMarker([lat,long],  #위도/경도
                        radius=geton_pm_top.loc[item,'저녁']/200,
                        popup=geton_pm_top.loc[item,'역명'],
                        color ='red',
                        fill = True).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2차(승차) 분석 내용

# %% [markdown]
# 1. 빨간색(저녁시간)만 있는 경우의 역들은  주요 직장((일자리)이 우세한 역이라고 볼수 있다. (남포, 중앙, 자갈치, 부산, 부산진, 범일,범내골,양정,센텀시티,해운대 등)
# 2. 파란색(아침시간)만 있는 경우 역들은 주요 주거지역(주택가)이 더 우세하다고 볼수 있다. (괴정,개금,대연, 광안, 벡스코, 사직, 미남, 명륜, 남산성, 수정, 화명,두실, 범어사 )
# 3. 둘다 top 30 에 들어간 역들은 주거지역과 일자리 지역이 혼재 된 지역이라 볼 수 있다. (사상, 연산, 교대, 동래, 하단, 수영,장산 : 하차분석의 센텀시티의 경우는 제외됨)
# 4. 서면과 부산역의 경우 부산의 중심지로서 주거/일자리와 상관없이 이용객이 많다고 볼수 있고, 부산대와 경성대부경대역은 대학생들의 이용객이 많아서 출근시간(파란색)대에 top30안에 포함된것으로 추정된다.

# %% [markdown]
# # 승차 기준 아침-저녁 갭으로 분석하기

# %% [markdown]
# ** 예상 시나리오 : 갭차이 상위 10, 하위 10개 , 각 20개의 아침,저녁 승차인원 차이 체크
# 1. 아침> 저녁 : 주거가 우세한 지역
# 2. 저녁> 아침 : 직장(일자리)가 우세한 지역

# %%
df_geton_day.head(10)
# Out:
#                                           아침           저녁
# 역번호 역명     역위도       역경도
# 119 1서면    35.158282 129.059556  1726.712329  6926.323288
# 206 센텀시티   35.168827 129.131745  1017.202740  5037.479452
# 219 2서면    35.157740 129.059084  1208.567123  4873.791781
# 111 남포     35.097953 129.034869  1330.339726  4204.605479
# 227 사상     35.162361 128.984621  2174.693151  4107.769863
# 113 부산역    35.115224 129.039700  1352.046575  4061.690411
# 112 중앙     35.103837 129.036371   590.235616  3317.515068
# 110 자갈치    35.097372 129.026670   886.490411  3296.950685
# 102 하단     35.106180 128.966803  2735.465753  3269.120548
# 212 경성대부경대 35.137585 129.100548  2180.997260  2921.895890

# %%
df_geton_day['차이'] = df_geton_day['아침']-df_geton_day['저녁']
df_geton_day.head(10)
# Out:
#                                           아침           저녁           차이
# 역번호 역명     역위도       역경도
# 119 1서면    35.158282 129.059556  1726.712329  6926.323288 -5199.610959
# 206 센텀시티   35.168827 129.131745  1017.202740  5037.479452 -4020.276712
# 219 2서면    35.157740 129.059084  1208.567123  4873.791781 -3665.224658
# 111 남포     35.097953 129.034869  1330.339726  4204.605479 -2874.265753
# 227 사상     35.162361 128.984621  2174.693151  4107.769863 -1933.076712
# 113 부산역    35.115224 129.039700  1352.046575  4061.690411 -2709.643836
# 112 중앙     35.103837 129.036371   590.235616  3317.515068 -2727.279452
# 110 자갈치    35.097372 129.026670   886.490411  3296.950685 -2410.460274
# 102 하단     35.106180 128.966803  2735.465753  3269.120548  -533.654795
# 212 경성대부경대 35.137585 129.100548  2180.997260  2921.895890  -740.898630

# %%
#아침> 저녁 : 주거가 우세한 지역 : TOP 10
gotam = df_geton_day.sort_values(by='차이',ascending=False).head(10)
gotam
# Out:
#                                        아침           저녁           차이
# 역번호 역명  역위도       역경도
# 127 온천장 35.220249 129.086437  2895.197260  1835.394521  1059.802740
# 309 미남  35.205503 129.068061  2037.323288  1001.556164  1035.767123
# 234 수정  35.223356 129.009198  1561.090411   607.008219   954.082192
# 311 남산정 35.213340 129.023928  1378.213699   430.780822   947.432877
# 223 개금  35.153284 129.020533  1717.093151   806.304110   910.789041
# 208 수영  35.165227 129.114713  2559.890411  1659.857534   900.032877
# 236 율리  35.246714 129.012918  1250.473973   396.854795   853.619178
# 235 화명  35.236278 129.013918  1967.145205  1135.676712   831.468493
# 124 교대  35.196050 129.080035  2779.046575  1984.375342   794.671233
# 310 만덕  35.213000 129.036527  1231.873973   456.230137   775.643836

# %%
gotam=gotam.reset_index()
gotam
# Out:
#    역번호   역명        역위도         역경도           아침           저녁           차이
# 0  127  온천장  35.220249  129.086437  2895.197260  1835.394521  1059.802740
# 1  309   미남  35.205503  129.068061  2037.323288  1001.556164  1035.767123
# 2  234   수정  35.223356  129.009198  1561.090411   607.008219   954.082192
# 3  311  남산정  35.213340  129.023928  1378.213699   430.780822   947.432877
# 4  223   개금  35.153284  129.020533  1717.093151   806.304110   910.789041
# 5  208   수영  35.165227  129.114713  2559.890411  1659.857534   900.032877
# 6  236   율리  35.246714  129.012918  1250.473973   396.854795   853.619178
# 7  235   화명  35.236278  129.013918  1967.145205  1135.676712   831.468493
# 8  124   교대  35.196050  129.080035  2779.046575  1984.375342   794.671233
# 9  310   만덕  35.213000  129.036527  1231.873973   456.230137   775.643836

# %%
# 저녁> 아침 : 직장(일자리)가 우세한 지역 TOP 10
gotpm = df_geton_day.sort_values(by='차이',ascending=True).head(10)

# %%
gotpm=gotpm.reset_index()
gotpm
# Out:
#    역번호    역명        역위도         역경도           아침           저녁           차이
# 0  119   1서면  35.158282  129.059556  1726.712329  6926.323288 -5199.610959
# 1  206  센텀시티  35.168827  129.131745  1017.202740  5037.479452 -4020.276712
# 2  219   2서면  35.157740  129.059084  1208.567123  4873.791781 -3665.224658
# 3  111    남포  35.097953  129.034869  1330.339726  4204.605479 -2874.265753
# 4  112    중앙  35.103837  129.036371   590.235616  3317.515068 -2727.279452
# 5  113   부산역  35.115224  129.039700  1352.046575  4061.690411 -2709.643836
# 6  110   자갈치  35.097372  129.026670   886.490411  3296.950685 -2410.460274
# 7  227    사상  35.162361  128.984621  2174.693151  4107.769863 -1933.076712
# 8  117    범일  35.140952  129.059352  1046.419178  2857.641096 -1811.221918
# 9  128   부산대  35.229609  129.089358  1771.424658  2845.449315 -1074.024658

# %%
gotpm['차이'] =gotpm['차이'].abs()
gotpm
# Out:
#    역번호    역명        역위도         역경도           아침           저녁           차이
# 0  119   1서면  35.158282  129.059556  1726.712329  6926.323288  5199.610959
# 1  206  센텀시티  35.168827  129.131745  1017.202740  5037.479452  4020.276712
# 2  219   2서면  35.157740  129.059084  1208.567123  4873.791781  3665.224658
# 3  111    남포  35.097953  129.034869  1330.339726  4204.605479  2874.265753
# 4  112    중앙  35.103837  129.036371   590.235616  3317.515068  2727.279452
# 5  113   부산역  35.115224  129.039700  1352.046575  4061.690411  2709.643836
# 6  110   자갈치  35.097372  129.026670   886.490411  3296.950685  2410.460274
# 7  227    사상  35.162361  128.984621  2174.693151  4107.769863  1933.076712
# 8  117    범일  35.140952  129.059352  1046.419178  2857.641096  1811.221918
# 9  128   부산대  35.229609  129.089358  1771.424658  2845.449315  1074.024658

# %%
#승차기준 아침/저녁 차이 상 하위 top 결합하기
gotall= pd.concat([gotam,gotpm])
gotall
# Out:
#    역번호    역명        역위도         역경도           아침           저녁           차이
# 0  127   온천장  35.220249  129.086437  2895.197260  1835.394521  1059.802740
# 1  309    미남  35.205503  129.068061  2037.323288  1001.556164  1035.767123
# 2  234    수정  35.223356  129.009198  1561.090411   607.008219   954.082192
# 3  311   남산정  35.213340  129.023928  1378.213699   430.780822   947.432877
# 4  223    개금  35.153284  129.020533  1717.093151   806.304110   910.789041
# 5  208    수영  35.165227  129.114713  2559.890411  1659.857534   900.032877
# 6  236    율리  35.246714  129.012918  1250.473973   396.854795   853.619178
# 7  235    화명  35.236278  129.013918  1967.145205  1135.676712   831.468493
# 8  124    교대  35.196050  129.080035  2779.046575  1984.375342   794.671233
# 9  310    만덕  35.213000  129.036527  1231.873973   456.230137   775.643836
# 0  119   1서면  35.158282  129.059556  1726.712329  6926.323288  5199.610959
# 1  206  센텀시티  35.168827  129.131745  1017.202740  5037.479452  4020.276712
# 2  219   2서면  35.157740  129.059084  1208.567123  4873.791781  3665.224658
# 3  111    남포  35.097953  129.034869  1330.339726  4204.605479  2874.265753
# 4  112    중앙  35.103837  129.036371   590.235616  3317.515068  2727.279452
# 5  113   부산역  35.115224  129.039700  1352.046575  4061.690411  2709.643836
# 6  110   자갈치  35.097372  129.026670   886.490411  3296.950685  2410.460274
# 7  227    사상  35.162361  128.984621  2174.693151  4107.769863  1933.076712
# 8  117    범일  35.140952  129.059352  1046.419178  2857.641096  1811.221918
# 9  128   부산대  35.229609  129.089358  1771.424658  2845.449315  1074.024658

# %%
gotall['역위도']
#geton_pm_top.info()
# Out:
# 0    35.220249
# 1    35.205503
# 2    35.223356
# 3    35.213340
# 4    35.153284
# 5    35.165227
# 6    35.246714
# 7    35.236278
# 8    35.196050
# 9    35.213000
# 0    35.158282
# 1    35.168827
# 2    35.157740
# 3    35.097953
# 4    35.103837
# 5    35.115224
# 6    35.097372
# 7    35.162361
# 8    35.140952
# 9    35.229609
# Name: 역위도, dtype: float64

# %%
gotall= gotall.reset_index()
gotall
# Out:
#     index  역번호    역명        역위도         역경도           아침           저녁  \
# 0       0  127   온천장  35.220249  129.086437  2895.197260  1835.394521
# 1       1  309    미남  35.205503  129.068061  2037.323288  1001.556164
# 2       2  234    수정  35.223356  129.009198  1561.090411   607.008219
# 3       3  311   남산정  35.213340  129.023928  1378.213699   430.780822
# 4       4  223    개금  35.153284  129.020533  1717.093151   806.304110
# 5       5  208    수영  35.165227  129.114713  2559.890411  1659.857534
# 6       6  236    율리  35.246714  129.012918  1250.473973   396.854795
# 7       7  235    화명  35.236278  129.013918  1967.145205  1135.676712
# 8       8  124    교대  35.196050  129.080035  2779.046575  1984.375342
# 9       9  310    만덕  35.213000  129.036527  1231.873973   456.230137
# 10      0  119   1서면  35.158282  129.059556  1726.712329  6926.323288
# 11      1  206  센텀시티  35.168827  129.131745  1017.202740  5037.479452
# 12      2  219   2서면  35.157740  129.059084  1208.567123  4873.791781
# 13      3  111    남포  35.097953  129.034869  1330.339726  4204.605479
# 14      4  112    중앙  35.103837  129.036371   590.235616  3317.515068
# 15      5  113   부산역  35.115224  129.039700  1352.046575  4061.690411
# 16      6  110   자갈치  35.097372  129.026670   886.490411  3296.950685
# 17      7  227    사상  35.162361  128.984621  2174.693151  4107.769863
# 18      8  117    범일  35.140952  129.059352  1046.419178  2857.641096
# 19      9  128   부산대  35.229609  129.089358  1771.424658  2845.449315
#
#              차이
# 0   1059.802740
# 1   1035.767123
# 2    954.082192
# 3    947.432877
# 4    910.789041
# 5    900.032877
# 6    853.619178
# 7    831.468493
# 8    794.671233
# 9    775.643836
# 10  5199.610959
# 11  4020.276712
# 12  3665.224658
# 13  2874.265753
# 14  2727.279452
# 15  2709.643836
# 16  2410.460274
# 17  1933.076712
# 18  1811.221918
# 19  1074.024658

# %%
#지도 시각화 
import folium
map_osm = folium.Map(location=[35.166804,129.083479], zoom_start=12)   # 지도 초기 로딩위치

# %%
#지도로 출근시간(아침) 이용객 표시
for item in gotall.index:
    lat = gotall.loc[item,'역위도']
    long = gotall.loc[item,'역경도']
    folium.CircleMarker([lat,long],  #위도/경도
                        radius=gotall.loc[item,'아침']/200,
                        popup=gotall.loc[item,'역명'],
                        color ='blue',
                        fill = True).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도로 퇴근시간(저녁) 이용객 표시
for item in gotall.index:
    lat = gotall.loc[item,'역위도']
    long = gotall.loc[item,'역경도']
    folium.CircleMarker([lat,long],  #위도/경도
                        radius=gotall.loc[item,'저녁']/200,
                        popup=gotall.loc[item,'역명'],
                        color ='red',
                        fill = True).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3차 분석 : 승차기준 아침/저녁 이용인원 갭차이

# %% [markdown]
# 1. 저녁시간(빨간색) 서클이 더 큰 경우 일자리 우선 지역 (서면, 센텀시티, 범일 사상, 중앙, 남포, 자갈치)
# 2. 아침시간(파란색) 서클이 더 큰 경우 주거 우선지역 (교대, 온천장, 수영, 화명, 수정,만덕, 남산성, 미남)
# 3. 분석의 한계 : 광역 환승(김해경전철, 동해남부서)에 해당하는 사상, 교대 등에 대해서는 추가 분석이 필요함
